# %% [markdown]
# # Pandas Tips & Review
# ### As a data scientist, you will be utilizing the pandas library in various ways to solve some of the world's most pressing issues
#
#
# ### Here are some useful pandas methods to manipulate dataframes to do and show us whatever we want!

# %% [markdown]
# ![Alt Text](https://media.giphy.com/media/aUhEBE0T8XNHa/giphy.gif)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Pandas Display Settings

# %%
absent = pd.read_csv('Absenteeism_at_work.csv', delimiter=';')
absent
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 0                       289                               36            13
# 1                       118                               13            18
# 2                       179                               51            18
# 3                       279                                5            14
# 4                       289                               36            13
# ..                      ...                              ...           ...
# 735                     289                               36            13
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 0     33                 239.554  ...                     0          1    2
# 1     50                 239.554  ...                     1          1    1
# 2     38                 239.554  ...                     0          1    0
# 3     39                 239.554  ...                     0          1    2
# 4     33                 239.554  ...                     0          1    2
# ..   ...                     ...  ...                   ...        ...  ...
# 735   33                 264.604  ...                     0          1    2
# 736   37                 264.604  ...                     0          3    1
# 737   40                 271.219  ...                     0          1    1
# 738   39                 271.219  ...                     0          1    2
# 739   53                 271.219  ...                     0          1    1
#
#      Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0                 1              0    1      90     172               30
# 1                 1              0    0      98     178               31
# 2                 1              0    0      89     170               31
# 3                 1              1    0      68     168               24
# 4                 1              0    1      90     172               30
# ..              ...            ...  ...     ...     ...              ...
# 735               1              0    1      90     172               30
# 736               0              0    1      88     172               29
# 737               1              0    8      98     170               34
# 738               1              0    2     100     170               35
# 739               0              0    1      77     175               25
#
#      Absenteeism time in hours
# 0                            4
# 1                            0
# 2                            2
# 3                            4
# 4                            2
# ..                         ...
# 735                          8
# 736                          4
# 737                          0
# 738                          0
# 739                          0
#
# [740 rows x 21 columns]

# %% [markdown]
# Notice how the columns and rows are truncated?  Let's work on fixing this using pandas display settings!

# %%
#viewing our current settings
print(pd.options.display.max_columns)
print(pd.options.display.max_rows)
# Out:
# 20
# 60

# %%
#adjusting settings
pd.options.display.max_columns = 50
pd.options.display.max_rows = None

# %%
#reviewing our settings
print(pd.options.display.max_columns)
print(pd.options.display.max_rows)
# Out:
# 50
# None

# %%
#checking our dataframe again to see if our settings worked
absent.head(30)
# Out:
#     ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0   11                  26                 7                3        1
# 1   36                   0                 7                3        1
# 2    3                  23                 7                4        1
# 3    7                   7                 7                5        1
# 4   11                  23                 7                5        1
# 5    3                  23                 7                6        1
# 6   10                  22                 7                6        1
# 7   20                  23                 7                6        1
# 8   14                  19                 7                2        1
# 9    1                  22                 7                2        1
# 10  20                   1                 7                2        1
# 11  20                   1                 7                3        1
# 12  20                  11                 7                4        1
# 13   3                  11                 7                4        1
# 14   3                  23                 7                4        1
# 15  24                  14                 7                6        1
# 16   3                  23                 7                6        1
# 17   3                  21                 7                2        1
# 18   6                  11                 7                5        1
# 19  33                  23                 8                4        1
# 20  18                  10                 8                4        1
# 21   3                  11                 8                2        1
# 22  10                  13                 8                2        1
# 23  20                  28                 8                6        1
# 24  11                  18                 8                2        1
# 25  10                  25                 8                2        1
# 26  11                  23                 8                3        1
# 27  30                  28                 8                4        1
# 28  11                  18                 8                4        1
# 29   3                  23                 8                6        1
#
#     Transportation expense  Distance from Residence to Work  Service time  \
# 0                      289                               36            13
# 1                      118                               13            18
# 2                      179                               51            18
# 3                      279                                5            14
# 4                      289                               36            13
# 5                      179                               51            18
# 6                      361                               52             3
# 7                      260                               50            11
# 8                      155                               12            14
# 9                      235                               11            14
# 10                     260                               50            11
# 11                     260                               50            11
# 12                     260                               50            11
# 13                     179                               51            18
# 14                     179                               51            18
# 15                     246                               25            16
# 16                     179                               51            18
# 17                     179                               51            18
# 18                     189                               29            13
# 19                     248                               25            14
# 20                     330                               16             4
# 21                     179                               51            18
# 22                     361                               52             3
# 23                     260                               50            11
# 24                     289                               36            13
# 25                     361                               52             3
# 26                     289                               36            13
# 27                     157                               27             6
# 28                     289                               36            13
# 29                     179                               51            18
#
#     Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# 0    33                 239.554          97                     0          1
# 1    50                 239.554          97                     1          1
# 2    38                 239.554          97                     0          1
# 3    39                 239.554          97                     0          1
# 4    33                 239.554          97                     0          1
# 5    38                 239.554          97                     0          1
# 6    28                 239.554          97                     0          1
# 7    36                 239.554          97                     0          1
# 8    34                 239.554          97                     0          1
# 9    37                 239.554          97                     0          3
# 10   36                 239.554          97                     0          1
# 11   36                 239.554          97                     0          1
# 12   36                 239.554          97                     0          1
# 13   38                 239.554          97                     0          1
# 14   38                 239.554          97                     0          1
# 15   41                 239.554          97                     0          1
# 16   38                 239.554          97                     0          1
# 17   38                 239.554          97                     0          1
# 18   33                 239.554          97                     0          1
# 19   47                 205.917          92                     0          1
# 20   28                 205.917          92                     0          2
# 21   38                 205.917          92                     0          1
# 22   28                 205.917          92                     0          1
# 23   36                 205.917          92                     0          1
# 24   33                 205.917          92                     0          1
# 25   28                 205.917          92                     0          1
# 26   33                 205.917          92                     0          1
# 27   29                 205.917          92                     0          1
# 28   33                 205.917          92                     0          1
# 29   38                 205.917          92                     0          1
#
#     Son  Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0     2               1              0    1      90     172               30
# 1     1               1              0    0      98     178               31
# 2     0               1              0    0      89     170               31
# 3     2               1              1    0      68     168               24
# 4     2               1              0    1      90     172               30
# 5     0               1              0    0      89     170               31
# 6     1               1              0    4      80     172               27
# 7     4               1              0    0      65     168               23
# 8     2               1              0    0      95     196               25
# 9     1               0              0    1      88     172               29
# 10    4               1              0    0      65     168               23
# 11    4               1              0    0      65     168               23
# 12    4               1              0    0      65     168               23
# 13    0               1              0    0      89     170               31
# 14    0               1              0    0      89     170               31
# 15    0               1              0    0      67     170               23
# 16    0               1              0    0      89     170               31
# 17    0               1              0    0      89     170               31
# 18    2               0              0    2      69     167               25
# 19    2               0              0    1      86     165               32
# 20    0               0              0    0      84     182               25
# 21    0               1              0    0      89     170               31
# 22    1               1              0    4      80     172               27
# 23    4               1              0    0      65     168               23
# 24    2               1              0    1      90     172               30
# 25    1               1              0    4      80     172               27
# 26    2               1              0    1      90     172               30
# 27    0               1              1    0      75     185               22
# 28    2               1              0    1      90     172               30
# 29    0               1              0    0      89     170               31
#
#     Absenteeism time in hours
# 0                           4
# 1                           0
# 2                           2
# 3                           4
# 4                           2
# 5                           2
# 6                           8
# 7                           4
# 8                          40
# 9                           8
# 10                          8
# 11                          8
# 12                          8
# 13                          1
# 14                          4
# 15                          8
# 16                          2
# 17                          8
# 18                          8
# 19                          2
# 20                          8
# 21                          1
# 22                         40
# 23                          4
# 24                          8
# 25                          7
# 26                          1
# 27                          4
# 28                          8
# 29                          2

# %% [markdown]
# ## Working with multiple dataframes
#
# #### One way to combine two datasets together is to use the the merge function from pandas
#
# Let's take a look at the `.merge()` documentation in pandas before we begin [pandas.DataFrame.merge](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html)

# %%
df1 = pd.read_csv('heart.csv')
df1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df2 = pd.DataFrame(np.random.randint(0,100,size=(1025,3)), columns=['B','C','D'])
df2.head()
# Out:
#     B   C   D
# 0   5  63  31
# 1  95  17  76
# 2  16  93  40
# 3  11  56  74
# 4  96  48   6

# %%
#merge df1 and df2
#df1.merge(df2, left_index=True, right_index=True)

# %%
merged_df = pd.merge(df1, df2, left_index=True, right_index=True)
merged_df.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      4.4
# 7    55    1   0       160   289    0        0      145      1      0.8
# 8    46    1   0       120   249    0        0      144      0      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
# 11   43    0   0       132   341    1        0      136      1      3.0
# 12   34    0   1       118   210    0        1      192      0      0.7
# 13   51    1   0       140   298    0        1      122      1      4.2
# 14   52    1   0       128   204    1        1      156      1      1.0
# 15   34    0   1       118   210    0        1      192      0      0.7
# 16   51    0   2       140   308    0        0      142      0      1.5
# 17   54    1   0       124   266    0        0      109      1      2.2
# 18   50    0   1       120   244    0        1      162      0      1.1
# 19   58    1   2       140   211    1        0      165      0      0.0
#
#     slope  ca  thal  target   B   C   D
# 0       2   2     3       0   5  63  31
# 1       0   0     3       0  95  17  76
# 2       0   0     3       0  16  93  40
# 3       2   1     3       0  11  56  74
# 4       1   3     2       0  96  48   6
# 5       1   0     2       1  33  20  15
# 6       0   3     1       0  18  71  53
# 7       1   1     3       0  22   2  39
# 8       2   0     3       0  11   2  11
# 9       1   2     2       0  90  89  26
# 10      1   0     2       1  96  58  75
# 11      1   0     3       0  78  68  28
# 12      2   0     2       1  33  29  55
# 13      1   3     3       0  32  71  58
# 14      1   0     0       0  57  54  89
# 15      2   0     2       1  85  57   8
# 16      2   1     2       1  90  63  79
# 17      1   1     3       0   4  80  34
# 18      2   0     2       1  88  81  80
# 19      2   0     2       1   3  83  70

# %% [markdown]
# ####  Another method to join two dataframes is to use the `.join` method
#
# [pandas.DataFrame.join](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html)
#
# ![](img/join-types.jpg)

# %%
#join df1 and df2
joined_df = df1.join(df2, on=df1.index)
joined_df.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      4.4
# 7    55    1   0       160   289    0        0      145      1      0.8
# 8    46    1   0       120   249    0        0      144      0      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
# 11   43    0   0       132   341    1        0      136      1      3.0
# 12   34    0   1       118   210    0        1      192      0      0.7
# 13   51    1   0       140   298    0        1      122      1      4.2
# 14   52    1   0       128   204    1        1      156      1      1.0
# 15   34    0   1       118   210    0        1      192      0      0.7
# 16   51    0   2       140   308    0        0      142      0      1.5
# 17   54    1   0       124   266    0        0      109      1      2.2
# 18   50    0   1       120   244    0        1      162      0      1.1
# 19   58    1   2       140   211    1        0      165      0      0.0
#
#     slope  ca  thal  target   B   C   D
# 0       2   2     3       0   5  63  31
# 1       0   0     3       0  95  17  76
# 2       0   0     3       0  16  93  40
# 3       2   1     3       0  11  56  74
# 4       1   3     2       0  96  48   6
# 5       1   0     2       1  33  20  15
# 6       0   3     1       0  18  71  53
# 7       1   1     3       0  22   2  39
# 8       2   0     3       0  11   2  11
# 9       1   2     2       0  90  89  26
# 10      1   0     2       1  96  58  75
# 11      1   0     3       0  78  68  28
# 12      2   0     2       1  33  29  55
# 13      1   3     3       0  32  71  58
# 14      1   0     0       0  57  54  89
# 15      2   0     2       1  85  57   8
# 16      2   1     2       1  90  63  79
# 17      1   1     3       0   4  80  34
# 18      2   0     2       1  88  81  80
# 19      2   0     2       1   3  83  70

# %% [markdown]
# #### We can also join two dataframes using the `.concat` function.  This function allows us to add new rows to our dataframe or new columns.
#
# [pandas.concat documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html)

# %%
# creating a new dataframe with columns
df4 = pd.DataFrame(np.random.randint(0,100,size=(1025,3)), columns=['Chemical_A','Chemical_B','Chemical_C'])
df4.head()
# Out:
#    Chemical_A  Chemical_B  Chemical_C
# 0          59          37           9
# 1          99          89          66
# 2           3          49          66
# 3          15          71          85
# 4          87          22          50

# %%
#adding new columns to dataframe using concat
df5 = pd.concat([merged_df, df4], axis=1)
df5.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      4.4
# 7    55    1   0       160   289    0        0      145      1      0.8
# 8    46    1   0       120   249    0        0      144      0      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
# 11   43    0   0       132   341    1        0      136      1      3.0
# 12   34    0   1       118   210    0        1      192      0      0.7
# 13   51    1   0       140   298    0        1      122      1      4.2
# 14   52    1   0       128   204    1        1      156      1      1.0
# 15   34    0   1       118   210    0        1      192      0      0.7
# 16   51    0   2       140   308    0        0      142      0      1.5
# 17   54    1   0       124   266    0        0      109      1      2.2
# 18   50    0   1       120   244    0        1      162      0      1.1
# 19   58    1   2       140   211    1        0      165      0      0.0
#
#     slope  ca  thal  target   B   C   D  Chemical_A  Chemical_B  Chemical_C
# 0       2   2     3       0   5  63  31          59          37           9
# 1       0   0     3       0  95  17  76          99          89          66
# 2       0   0     3       0  16  93  40           3          49          66
# 3       2   1     3       0  11  56  74          15          71          85
# 4       1   3     2       0  96  48   6          87          22          50
# 5       1   0     2       1  33  20  15          82          69          78
# 6       0   3     1       0  18  71  53          13          20          67
# 7       1   1     3       0  22   2  39          57          52          67
# 8       2   0     3       0  11   2  11          67          41           1
# 9       1   2     2       0  90  89  26          70          68          20
# 10      1   0     2       1  96  58  75           5          68          81
# 11      1   0     3       0  78  68  28          67          45          60
# 12      2   0     2       1  33  29  55          99          52          85
# 13      1   3     3       0  32  71  58          19           9          94
# 14      1   0     0       0  57  54  89          39          38          40
# 15      2   0     2       1  85  57   8          57          43          64
# 16      2   1     2       1  90  63  79          79          14          54
# 17      1   1     3       0   4  80  34          69           8          52
# 18      2   0     2       1  88  81  80          15          49          81
# 19      2   0     2       1   3  83  70          95          66          16

# %%
#creating a new row

df6 = pd.DataFrame({'age':[54, 72], 'sex':[1,0], "threstbps":[150, 143], 'chol':[276, 212], \
                    'fbs':[0, 1], 'restecg': [1, 0], 'thalach':[146, 171], 'exang':[0, 0], \
                    'oldpeak': [0.5, 2.9], 'slope':[1, 2], "ca" :[2, 0], "thal":[2, 2], \
                    "target": [1, 0], 'B':[25, 58], "C":[23, 84], "D":[40, 57], "Chemical_A":[3, 84], \
                    "Chemical_B":[43, 71], "Chemical_C": [45, 92]})
df6
# Out:
#    age  sex  threstbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   54    1        150   276    0        1      146      0      0.5      1
# 1   72    0        143   212    1        0      171      0      2.9      2
#
#    ca  thal  target   B   C   D  Chemical_A  Chemical_B  Chemical_C
# 0   2     2       1  25  23  40           3          43          45
# 1   0     2       0  58  84  57          84          71          92

# %%
#concat row
df7 = pd.concat([df5, df6], axis = 0)
df7.tail(20)
# Out:
#       age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1007   56    1  3.0     120.0   193    0        0      162      0      1.9
# 1008   42    1  1.0     120.0   295    0        1      162      0      0.0
# 1009   40    1  0.0     152.0   223    0        1      181      0      0.0
# 1010   51    1  0.0     140.0   299    0        1      173      1      1.6
# 1011   45    1  1.0     128.0   308    0        0      170      0      0.0
# 1012   48    1  1.0     110.0   229    0        1      168      0      1.0
# 1013   58    1  0.0     114.0   318    0        2      140      0      4.4
# 1014   44    0  2.0     108.0   141    0        1      175      0      0.6
# 1015   58    1  0.0     128.0   216    0        0      131      1      2.2
# 1016   65    1  3.0     138.0   282    1        0      174      0      1.4
# 1017   53    1  0.0     123.0   282    0        1       95      1      2.0
# 1018   41    1  0.0     110.0   172    0        0      158      0      0.0
# 1019   47    1  0.0     112.0   204    0        1      143      0      0.1
# 1020   59    1  1.0     140.0   221    0        1      164      1      0.0
# 1021   60    1  0.0     125.0   258    0        0      141      1      2.8
# 1022   47    1  0.0     110.0   275    0        0      118      1      1.0
# 1023   50    0  0.0     110.0   254    0        0      159      0      0.0
# 1024   54    1  0.0     120.0   188    0        1      113      0      1.4
# 0      54    1  NaN       NaN   276    0        1      146      0      0.5
# 1      72    0  NaN       NaN   212    1        0      171      0      2.9
#
#       slope  ca  thal  target   B   C   D  Chemical_A  Chemical_B  Chemical_C  \
# 1007      1   0     3       1  70  76  24          60          13          49
# 1008      2   0     2       1  97   4  45          95          60          92
# 1009      2   0     3       0  86  26  54          99          52          29
# 1010      2   0     3       0  90   6  55          67          54          86
# 1011      2   0     2       1  24  66  20          24          20          86
# 1012      0   0     3       0  36  56   1          39          63          26
# 1013      0   3     1       0  29  87  75          95          84          70
# 1014      1   0     2       1  35  66  88          75          41          52
# 1015      1   3     3       0   2   8   7          10          91          60
# 1016      1   1     2       0  39   6  20          75          61          60
# 1017      1   2     3       0  83  64  76          25          75          56
# 1018      2   0     3       0   8   8  26          15          93          75
# 1019      2   0     2       1  18  83  65          99          25          77
# 1020      2   0     2       1  93  31  97          41          13          48
# 1021      1   1     3       0  78  96   1          68          42          77
# 1022      1   1     2       0  98  92  55          70          52          80
# 1023      2   0     2       1  42  12   9          80          40           2
# 1024      1   1     3       0  64   6  41          12          52          85
# 0         1   2     2       1  25  23  40           3          43          45
# 1         2   0     2       0  58  84  57          84          71          92
#
#       threstbps
# 1007        NaN
# 1008        NaN
# 1009        NaN
# 1010        NaN
# 1011        NaN
# 1012        NaN
# 1013        NaN
# 1014        NaN
# 1015        NaN
# 1016        NaN
# 1017        NaN
# 1018        NaN
# 1019        NaN
# 1020        NaN
# 1021        NaN
# 1022        NaN
# 1023        NaN
# 1024        NaN
# 0         150.0
# 1         143.0

# %% [markdown]
# # Ways to utilize lambda functions
# #### .map(), .apply(), .applymap()

# %% [markdown]
# The map() method only works on pandas series

# %% [markdown]
# The apply () method works on panda series and data frames

# %% [markdown]
# The applymap() method works on the entire pandas data frame where the input function is applied to every element individually. In other words, applymap() is apply() + map()!

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
new_df = df.age.map(lambda x: x * 10)
new_df.head()
# Out:
# 0    520
# 1    530
# 2    700
# 3    610
# 4    620
# Name: age, dtype: int64

# %%
super_df = df.apply(lambda x: x * 10)
super_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0  520   10   0      1250  2120    0       10     1680      0     10.0     20
# 1  530   10   0      1400  2030   10        0     1550     10     31.0      0
# 2  700   10   0      1450  1740    0       10     1250     10     26.0      0
# 3  610   10   0      1480  2030    0       10     1610      0      0.0     20
# 4  620    0   0      1380  2940   10       10     1060      0     19.0     10
#
#    ca  thal  target
# 0  20    30       0
# 1   0    30       0
# 2   0    30       0
# 3  10    30       0
# 4  30    20       0

# %% [markdown]
# Do these two dataframes equal the same thing?

# %%
(new_df == super_df).value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-793ee5dcf1f8> in <module>
# ----> 1 (new_df == super_df).value_counts()
#
# ~\.conda\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
apply_df = df.applymap(lambda x: x*10)

# %%
apply_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0  520   10   0      1250  2120    0       10     1680      0     10.0     20
# 1  530   10   0      1400  2030   10        0     1550     10     31.0      0
# 2  700   10   0      1450  1740    0       10     1250     10     26.0      0
# 3  610   10   0      1480  2030    0       10     1610      0      0.0     20
# 4  620    0   0      1380  2940   10       10     1060      0     19.0     10
#
#    ca  thal  target
# 0  20    30       0
# 1   0    30       0
# 2   0    30       0
# 3  10    30       0
# 4  30    20       0

# %% [markdown]
# #### How else could we manipulate the 'age' column?

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# #### We can also use these functions on strings.  Let's add a column of patient names to our dataset and manipulate those using a lambda function!

# %%
# !pip install faker
# Out:
# Requirement already satisfied: faker in c:\users\raven (work)\.conda\envs\learn-env\lib\site-packages (4.1.0)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\raven (work)\.conda\envs\learn-env\lib\site-packages (from faker) (2.8.0)
# Requirement already satisfied: text-unidecode==1.3 in c:\users\raven (work)\.conda\envs\learn-env\lib\site-packages (from faker) (1.3)
# Requirement already satisfied: six>=1.5 in c:\users\raven (work)\.conda\envs\learn-env\lib\site-packages (from python-dateutil>=2.4->faker) (1.12.0)

# %%
from faker import Faker
fake = Faker()
fake.name()
# Out:
# 'Nancy Shannon'

# %% [markdown]
# Let's generate a column of names

# %%
#creating patient names
df['name'] = [fake.name() for x in range(1025)]
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target                   name
# 0   2     3       0          Joshua Osborn
# 1   0     3       0             Shane King
# 2   0     3       0  Mrs. Aimee Holland MD
# 3   1     3       0         Tiffany Conway
# 4   3     2       0       Olivia Rodriguez

# %%
#replacing the spaces in each name with an _
df.name = df.name.map(lambda x: x.replace(" ", "_"))
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target                   name
# 0   2     3       0          Joshua_Osborn
# 1   0     3       0             Shane_King
# 2   0     3       0  Mrs._Aimee_Holland_MD
# 3   1     3       0         Tiffany_Conway
# 4   3     2       0       Olivia_Rodriguez

# %% [markdown]
# # Transposing Data
#
# There are a variety of ways you might want to transpose your dataframe.  One thing you might want to do is turn columns into rows.  You can do this very easily using the `.transpose` or `.t` function.
#
# [Pandas Transpose](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.transpose.html)

# %%
df.T
# Out:
#                    0           1                      2               3     \
# age                  52          53                     70              61
# sex                   1           1                      1               1
# cp                    0           0                      0               0
# trestbps            125         140                    145             148
# chol                212         203                    174             203
# fbs                   0           1                      0               0
# restecg               1           0                      1               1
# thalach             168         155                    125             161
# exang                 0           1                      1               0
# oldpeak               1         3.1                    2.6               0
# slope                 2           0                      0               2
# ca                    2           0                      0               1
# thal                  3           3                      3               3
# target                0           0                      0               0
# name      Joshua_Osborn  Shane_King  Mrs._Aimee_Holland_MD  Tiffany_Conway
#
#                       4          5             6                  7     \
# age                     62         58            58                 55
# sex                      0          0             1                  1
# cp                       0          0             0                  0
# trestbps               138        100           114                160
# chol                   294        248           318                289
# fbs                      1          0             0                  0
# restecg                  1          0             2                  0
# thalach                106        122           140                145
# exang                    0          0             0                  1
# oldpeak                1.9          1           4.4                0.8
# slope                    1          1             0                  1
# ca                       3          0             3                  1
# thal                     2          2             1                  3
# target                   0          1             0                  0
# name      Olivia_Rodriguez  Mark_Reed  Kimberly_Fry  Jillian_Brock_PhD
#
#                     8                 9             10            11    \
# age                   46                54            71            43
# sex                    1                 1             0             0
# cp                     0                 0             0             0
# trestbps             120               122           112           132
# chol                 249               286           149           341
# fbs                    0                 0             0             1
# restecg                0                 0             1             0
# thalach              144               116           125           136
# exang                  0                 1             0             1
# oldpeak              0.8               3.2           1.6             3
# slope                  2                 1             1             1
# ca                     0                 2             0             0
# thal                   3                 2             2             3
# target                 0                 0             1             0
# name      Courtney_Brown  Stacey_Mcpherson  Jeffrey_Rose  Brian_Romero
#
#                     12               13              14             15    \
# age                   34               51              52             34
# sex                    0                1               1              0
# cp                     1                0               0              1
# trestbps             118              140             128            118
# chol                 210              298             204            210
# fbs                    0                0               1              0
# restecg                1                1               1              1
# thalach              192              122             156            192
# exang                  0                1               1              0
# oldpeak              0.7              4.2               1            0.7
# slope                  2                1               1              2
# ca                     0                3               0              0
# thal                   2                3               0              2
# target                 1                0               0              1
# name      Brandon_Graves  Samantha_Powell  Katrina_Hester  George_Durham
#
#                     16           17               18                  19    \
# age                   51           54               50                  58
# sex                    0            1                0                   1
# cp                     2            0                1                   2
# trestbps             140          124              120                 140
# chol                 308          266              244                 211
# fbs                    0            0                0                   1
# restecg                0            0                1                   0
# thalach              142          109              162                 165
# exang                  0            1                0                   0
# oldpeak              1.5          2.2              1.1                   0
# slope                  2            1                2                   2
# ca                     1            1                0                   0
# thal                   2            3                2                   2
# target                 1            0                1                   1
# name      Regina_Donovan  Tracy_Gross  Cheryl_Guerrero  Ms._Alexis_Long_MD
#
#                    20            21               22                23    \
# age                  60            67               45                63
# sex                   1             0                1                 0
# cp                    2             0                0                 2
# trestbps            140           106              104               135
# chol                185           223              208               252
# fbs                   0             0                0                 0
# restecg               0             1                0                 0
# thalach             155           142              148               172
# exang                 0             0                1                 0
# oldpeak               3           0.3                3                 0
# slope                 1             2                1                 2
# ca                    0             2                0                 0
# thal                  2             2                2                 2
# target                0             1                1                 1
# name      Krista_Jordan  Nancy_Garcia  Jennifer_Adkins  Steven_Henderson
#
#                  24    ...             1000         1001           1002  \
# age                42  ...               64           42             66
# sex                 0  ...                1            1              1
# cp                  2  ...                0            0              0
# trestbps          120  ...              145          140            112
# chol              209  ...              212          226            212
# fbs                 0  ...                0            0              0
# restecg             1  ...                0            1              0
# thalach           173  ...              132          178            132
# exang               0  ...                0            0              1
# oldpeak             0  ...                2            0            0.1
# slope               1  ...                1            2              2
# ca                  0  ...                2            0              1
# thal                2  ...                1            2              2
# target              1  ...                0            1              0
# name      Tanya_Cowan  ...  Matthew_Ferrell  Clinton_Lin  Robin_Johnson
#
#                    1003             1004             1005           1006  \
# age                  52               51               55             58
# sex                   1                0                0              1
# cp                    0                2                0              2
# trestbps            108              140              128            140
# chol                233              308              205            211
# fbs                   1                0                0              1
# restecg               1                0                2              0
# thalach             147              142              130            165
# exang                 0                0                1              0
# oldpeak             0.1              1.5                2              0
# slope                 2                2                1              2
# ca                    3                1                1              0
# thal                  3                2                3              2
# target                1                1                0              1
# name      Leslie_Martin  Matthew_Elliott  Chelsea_Schmidt  Edward_Wagner
#
#                      1007            1008           1009                 1010  \
# age                    56              42             40                   51
# sex                     1               1              1                    1
# cp                      3               1              0                    0
# trestbps              120             120            152                  140
# chol                  193             295            223                  299
# fbs                     0               0              0                    0
# restecg                 0               1              1                    1
# thalach               162             162            181                  173
# exang                   0               0              0                    1
# oldpeak               1.9               0              0                  1.6
# slope                   1               2              2                    2
# ca                      0               0              0                    0
# thal                    3               2              3                    3
# target                  1               1              0                    0
# name      Kendra_Robinson  Gregory_Walker  Alvin_Simmons  Christina_Hernandez
#
#                         1011            1012                 1013  \
# age                       45              48                   58
# sex                        1               1                    1
# cp                         1               1                    0
# trestbps                 128             110                  114
# chol                     308             229                  318
# fbs                        0               0                    0
# restecg                    0               1                    2
# thalach                  170             168                  140
# exang                      0               0                    0
# oldpeak                    0               1                  4.4
# slope                      2               0                    0
# ca                         0               0                    3
# thal                       2               3                    1
# target                     1               0                    0
# name      Elizabeth_Martinez  Michael_Gibson  Jacqueline_Mcdonald
#
#                     1014           1015         1016           1017  \
# age                   44             58           65             53
# sex                    0              1            1              1
# cp                     2              0            3              0
# trestbps             108            128          138            123
# chol                 141            216          282            282
# fbs                    0              0            1              0
# restecg                1              0            0              1
# thalach              175            131          174             95
# exang                  0              1            0              1
# oldpeak              0.6            2.2          1.4              2
# slope                  1              1            1              1
# ca                     0              3            1              2
# thal                   2              3            2              3
# target                 1              0            0              0
# name      Jessica_Jarvis  Dustin_Miller  Karl_Deleon  Joseph_Watson
#
#                    1018          1019          1020         1021  \
# age                  41            47            59           60
# sex                   1             1             1            1
# cp                    0             0             1            0
# trestbps            110           112           140          125
# chol                172           204           221          258
# fbs                   0             0             0            0
# restecg               0             1             1            0
# thalach             158           143           164          141
# exang                 0             0             1            1
# oldpeak               0           0.1             0          2.8
# slope                 2             2             2            1
# ca                    0             0             0            1
# thal                  3             2             2            3
# target                0             1             1            0
# name      James_Bennett  Edwin_Bailey  James_Jensen  Rick_Morris
#
#                     1022          1023           1024
# age                   47            50             54
# sex                    1             0              1
# cp                     0             0              0
# trestbps             110           110            120
# chol                 275           254            188
# fbs                    0             0              0
# restecg                0             0              1
# thalach              118           159            113
# exang                  1             0              0
# oldpeak                1             0            1.4
# slope                  1             2              1
# ca                     1             0              1
# thal                   2             2              3
# target                 0             1              0
# name      Thomas_Alvarez  Ronnie_Lewis  Mary_Buchanan
#
# [15 rows x 1025 columns]

# %% [markdown]
# ### Pivot tables which you might be familiar with are also possible to create in pandas using the `.pivot_table()` function
#
# [pivot_table](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html)

# %%
df.pivot_table(index = 'sex' , columns='cp' , values='chol', aggfunc='mean', margins=True)
# Out:
# cp            0           1           2           3         All
# sex
# 0    266.616541  253.912281  260.889908  246.461538  261.455128
# 1    243.920330  239.927273  230.554286  235.156250  239.237027
# All  249.993964  244.700599  242.197183  237.064935  246.000000

# %%
#let's add some margins
df.pivot_table(index = 'sex', columns= 'cp', values="chol", aggfunc='mean')
# Out:
# cp            0           1           2           3
# sex
# 0    266.616541  253.912281  260.889908  246.461538
# 1    243.920330  239.927273  230.554286  235.156250

# %% [markdown]
# ### Another way to view information across two or more factors is to create a cross tabulation using the pandas `.crosstab` function
#
# [Pandas Crosstab](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html)

# %%
pd.crosstab(index=[df.sex, df.cp], columns=df.exang, margins=True)
# Out:
# exang     0    1   All
# sex cp
# 0   0    71   62   133
#     1    51    6    57
#     2   103    6   109
#     3    13    0    13
# 1   0   143  221   364
#     1   104    6   110
#     2   144   31   175
#     3    51   13    64
# All     680  345  1025
