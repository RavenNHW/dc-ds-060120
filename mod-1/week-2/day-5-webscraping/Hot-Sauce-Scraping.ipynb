# %% [markdown]
# # HEATHOTSAUCE.COM SCRAPE
#
# https://heathotsauce.com

# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %%
# scrape all 19 pages to get names and urls

names = []
urls = []

# go to each page (print progress)
for i in range(1, 19):
    url = 'https://heathotsauce.com/collections/all?page=' + str(i)
    page = requests.get(url)
    print (i, page)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    #in each page, scrape the names
    for j in soup.findAll('span', class_='title product-name-custom'):
        names.append(j.get_text())
    for k in soup.findAll(itemprop = 'url'):
        urls.append(k.get('href'))
# Out:
# 1 <Response [200]>

# %%
urls[:5]
# Out:
# ['https://heathotsauce.com/collections/all/products/1o8-garlic-basil-hot-sauce',
#  'https://heathotsauce.com/collections/all/products/24-karat-gold',
#  'https://heathotsauce.com/collections/all/products/357-gold-edition-w-no-9-plutonium',
#  'https://heathotsauce.com/collections/all/products/357-naga-morich-puree',
#  'https://heathotsauce.com/collections/all/products/reaper-puree-1']

# %%
#combine names and urls into a df
names_urls = pd.DataFrame({'names':names, 'urls':urls})

# add url to start of urls
names_urls['urls'] = names_urls['urls'].apply(lambda x: 'https://heathotsauce.com' + str(x))

# %%
names_urls
# Out:
#                               names  \
# 0                  1o8 Garlic Basil
# 1                     24 Karat Gold
# 2                  357 Gold Edition
# 3             357 Naga Morich Puree
# 4                  357 Reaper Puree
# ..                              ...
# 643                   Wuju Original
# 644  Xtra Virgin-Mildly Adulterated
# 645                   Xtreme Regret
# 646                  XXX Dime Sauce
# 647         Yai's Thai Chili Garlic
#
#                                                   urls
# 0    https://heathotsauce.com/collections/all/produ...
# 1    https://heathotsauce.com/collections/all/produ...
# 2    https://heathotsauce.com/collections/all/produ...
# 3    https://heathotsauce.com/collections/all/produ...
# 4    https://heathotsauce.com/collections/all/produ...
# ..                                                 ...
# 643  https://heathotsauce.com/collections/all/produ...
# 644  https://heathotsauce.com/collections/all/produ...
# 645  https://heathotsauce.com/collections/all/produ...
# 646  https://heathotsauce.com/collections/all/produ...
# 647  https://heathotsauce.com/collections/all/produ...
#
# [648 rows x 2 columns]

# %%
## Go to each unique url, grab name, price, manufacturer, description

## NOTE: I requested too many timesand was timed out. 
## Do this in batches, save as different df, then concat together

name = []
mfc = []
price = []
desc = []
urls = []

for n, url in enumerate(names_urls['urls'][:21]):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
#     name
    try:
        name.append(soup.find('h1', class_='product_name').get_text())
    except:
        name.append('')
#     manufacturer
    try:
        mfc.append(soup.find('p', class_='vendor').get_text())
    except:
        mfc.append('')
#     price
    try:
        price.append(soup.find('span', class_='money').get_text())
    except:
        price.append('')
#     description
    try:
        desc.append(soup.find('div', class_='description').get_text())
    except:
        desc.append('')
#     url
    try:
        urls.append(url)
    except:
        urls.append('')
    
#     print progress, if response != 200, stop kernel. you have been timed out
    print (n, page)

df_1 = pd.DataFrame({'names':name,
                   'mfc':mfc,
                   'price':price,
                   'desc':desc,
                   'url':urls})
# Out:
# 0 <Response [200]>
# 1 <Response [200]>
# 2 <Response [200]>
# 3 <Response [200]>
# 4 <Response [200]>
# 5 <Response [200]>
# 6 <Response [200]>
# 7 <Response [200]>
# 8 <Response [200]>
# 9 <Response [200]>
# 10 <Response [200]>
# 11 <Response [200]>
# 12 <Response [200]>
# 13 <Response [200]>
# 14 <Response [200]>
# 15 <Response [200]>
# 16 <Response [200]>
# 17 <Response [200]>
# 18 <Response [200]>
# 19 <Response [200]>
# 20 <Response [200]>

# %%
df_1
# Out:
#                                                names  \
# 0                               1o8 Garlic Basil
# 1                                  24 Karat Gold
# 2                               357 Gold Edition
# 3                          357 Naga Morich Puree
# 4                               357 Reaper Puree
# 5                              3o8 Garlic Ginger
# 6                                 4o8 Jerk Style
# 7                                  512 Pot Sauce
# 8                                   5o8 Chipotle
# 9                         6o8 Pineapple Habanero
# 10                                   7 Pot Panic
# 11                              7o8 7 Pot Citrus
# 12                             7o8 Optimus Primo
# 13                              8o8 Naga Jolokia
# 14                              8o8 Octo Maximus
# 15   Adoboloco "Maui No Ka Oi" Trinidad Scorpion
# 16                  Adoboloco Pineapple Habanero
# 17                       African Rhino Peri-Peri
# 18                             After Death Sauce
# 19                                      Aji Bomb
# 20                         Aji Panca Pepper Mash
#
#                             mfc    price  \
# 0                  \nBigfat's\n   $ 6.49
# 1            \nHotter Than El\n   $ 7.99
# 2                   \nMad Dog\n  $ 18.99
# 3                   \nMad Dog\n  $ 11.99
# 4                   \nMad Dog\n  $ 11.99
# 5                  \nBigfat's\n   $ 6.49
# 6                  \nBigfat's\n   $ 6.49
# 7                 \nMikey V's\n   $ 7.99
# 8                  \nBigfat's\n   $ 6.49
# 9                  \nBigfat's\n   $ 6.49
# 10               \nPexPeppers\n  $ 11.99
# 11                 \nBigfat's\n   $ 6.49
# 12                 \nBigfat's\n   $ 8.99
# 13                 \nBigfat's\n   $ 9.99
# 14                 \nBigfat's\n  $ 11.99
# 15                \nAdoboloco\n  $ 11.99
# 16                \nAdoboloco\n   $ 9.99
# 17  \nKalahari Pepper Company\n   $ 7.99
# 18                  \nBlair's\n   $ 7.99
# 19         \nVolcanic Peppers\n   $ 6.99
# 20        \nMagic Plant Farms\n   $ 9.99
#
#                                                  desc  \
# 0   \nA mellow sauce made with onions, tomatoes, g...
# 1   \nA classic habanero sauce with onions, carrot...
# 2   \nThis 25th Anniversary Gold Edition Sauce is ...
# 3   \nA puree rather than a hot sauce, this contai...
# 4   \nA puree of the worlds hottest pepper, the Ca...
# 5   \nA Thai inspired sauce with a hint of lemongr...
# 6   \nThis Jamaican Jerk style sauce is packed wit...
# 7   \nA mellow, creamy roasted Jalapeno & tomatill...
# 8   \nA tomato based sauce with a smoky chipotle f...
# 9   \nA fiery blend of pineapple, garlic, cilantro...
# 10  \nAn extra hot BBQ style sauce, made with pure...
# 11  \n7o8 is one of the most flavorful superhot sa...
# 12  \n7o8 Optimus Primo is a limited edition extre...
# 13  \nBig Fat's 8o8 Naga Jolokia is a seriously ho...
# 14  \nAn even hotter upgrade to the original 8o8, ...
# 15  \nMaui No Ka Oi (which means Maui is the best)...
# 16  \nThis sauce is dangerously addictive. The swe...
# 17  \nAfrican Rhino Peri-Peri hot sauce is made wi...
# 18  \nBlair's After Death Sauce is an extremely sp...
# 19  \nA delicious blend of Aji Panca and Amarillo ...
# 20  \n\nThis spicy Aji Panca pepper mash is perfec...
#
#                                                   url
# 0   https://heathotsauce.com/collections/all/produ...
# 1   https://heathotsauce.com/collections/all/produ...
# 2   https://heathotsauce.com/collections/all/produ...
# 3   https://heathotsauce.com/collections/all/produ...
# 4   https://heathotsauce.com/collections/all/produ...
# 5   https://heathotsauce.com/collections/all/produ...
# 6   https://heathotsauce.com/collections/all/produ...
# 7   https://heathotsauce.com/collections/all/produ...
# 8   https://heathotsauce.com/collections/all/produ...
# 9   https://heathotsauce.com/collections/all/produ...
# 10  https://heathotsauce.com/collections/all/produ...
# 11  https://heathotsauce.com/collections/all/produ...
# 12  https://heathotsauce.com/collections/all/produ...
# 13  https://heathotsauce.com/collections/all/produ...
# 14  https://heathotsauce.com/collections/all/produ...
# 15  https://heathotsauce.com/collections/all/produ...
# 16  https://heathotsauce.com/collections/all/produ...
# 17  https://heathotsauce.com/collections/all/produ...
# 18  https://heathotsauce.com/collections/all/produ...
# 19  https://heathotsauce.com/collections/all/produ...
# 20  https://heathotsauce.com/collections/all/produ...

# %%
# combine all df batches. strip manufacturers of \n
full_df = df_1
full_df['mfc'] = full_df['mfc'].apply(lambda x: x.strip())
full_df['desc'] = full_df['desc'].apply(lambda x: x.strip())

# remove gift sets and empty rows
full_df = full_df[full_df['mfc'] != 'Gift Set']
full_df = full_df[full_df['desc'] != '']
full_df.reset_index(inplace=True, drop=True)

# save df as csv
full_df.to_csv('hot_sauces.csv', encoding='utf-8', index=False)

# %%
full_df
# Out:
#                                                names                      mfc  \
# 0                               1o8 Garlic Basil                     Bigfat's
# 1                                  24 Karat Gold               Hotter Than El
# 2                               357 Gold Edition                      Mad Dog
# 3                          357 Naga Morich Puree                      Mad Dog
# 4                               357 Reaper Puree                      Mad Dog
# 5                              3o8 Garlic Ginger                     Bigfat's
# 6                                 4o8 Jerk Style                     Bigfat's
# 7                                  512 Pot Sauce                    Mikey V's
# 8                                   5o8 Chipotle                     Bigfat's
# 9                         6o8 Pineapple Habanero                     Bigfat's
# 10                                   7 Pot Panic                   PexPeppers
# 11                              7o8 7 Pot Citrus                     Bigfat's
# 12                             7o8 Optimus Primo                     Bigfat's
# 13                              8o8 Naga Jolokia                     Bigfat's
# 14                              8o8 Octo Maximus                     Bigfat's
# 15   Adoboloco "Maui No Ka Oi" Trinidad Scorpion                    Adoboloco
# 16                  Adoboloco Pineapple Habanero                    Adoboloco
# 17                       African Rhino Peri-Peri      Kalahari Pepper Company
# 18                             After Death Sauce                      Blair's
# 19                                      Aji Bomb             Volcanic Peppers
# 20                         Aji Panca Pepper Mash            Magic Plant Farms
#
#       price                                               desc  \
# 0    $ 6.49  A mellow sauce made with onions, tomatoes, gar...
# 1    $ 7.99  A classic habanero sauce with onions, carrots,...
# 2   $ 18.99  This 25th Anniversary Gold Edition Sauce is ma...
# 3   $ 11.99  A puree rather than a hot sauce, this contains...
# 4   $ 11.99  A puree of the worlds hottest pepper, the Caro...
# 5    $ 6.49  A Thai inspired sauce with a hint of lemongras...
# 6    $ 6.49  This Jamaican Jerk style sauce is packed with ...
# 7    $ 7.99  A mellow, creamy roasted Jalapeno & tomatillo ...
# 8    $ 6.49  A tomato based sauce with a smoky chipotle fla...
# 9    $ 6.49  A fiery blend of pineapple, garlic, cilantro, ...
# 10  $ 11.99  An extra hot BBQ style sauce, made with pureed...
# 11   $ 6.49  7o8 is one of the most flavorful superhot sauc...
# 12   $ 8.99  7o8 Optimus Primo is a limited edition extreme...
# 13   $ 9.99  Big Fat's 8o8 Naga Jolokia is a seriously hot ...
# 14  $ 11.99  An even hotter upgrade to the original 8o8, th...
# 15  $ 11.99  Maui No Ka Oi (which means Maui is the best) i...
# 16   $ 9.99  This sauce is dangerously addictive. The sweet...
# 17   $ 7.99  African Rhino Peri-Peri hot sauce is made with...
# 18   $ 7.99  Blair's After Death Sauce is an extremely spic...
# 19   $ 6.99  A delicious blend of Aji Panca and Amarillo Pe...
# 20   $ 9.99  This spicy Aji Panca pepper mash is perfect fo...
#
#                                                   url
# 0   https://heathotsauce.com/collections/all/produ...
# 1   https://heathotsauce.com/collections/all/produ...
# 2   https://heathotsauce.com/collections/all/produ...
# 3   https://heathotsauce.com/collections/all/produ...
# 4   https://heathotsauce.com/collections/all/produ...
# 5   https://heathotsauce.com/collections/all/produ...
# 6   https://heathotsauce.com/collections/all/produ...
# 7   https://heathotsauce.com/collections/all/produ...
# 8   https://heathotsauce.com/collections/all/produ...
# 9   https://heathotsauce.com/collections/all/produ...
# 10  https://heathotsauce.com/collections/all/produ...
# 11  https://heathotsauce.com/collections/all/produ...
# 12  https://heathotsauce.com/collections/all/produ...
# 13  https://heathotsauce.com/collections/all/produ...
# 14  https://heathotsauce.com/collections/all/produ...
# 15  https://heathotsauce.com/collections/all/produ...
# 16  https://heathotsauce.com/collections/all/produ...
# 17  https://heathotsauce.com/collections/all/produ...
# 18  https://heathotsauce.com/collections/all/produ...
# 19  https://heathotsauce.com/collections/all/produ...
# 20  https://heathotsauce.com/collections/all/produ...
